# %%
import pandas as pd
from pandas import DataFrame
import pyodbc
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression

# %%
#kết nối với db
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};' 'SERVER= MSI;' 'DATABASE=AdventureWorksLT2022;''UID=dh;''PWD=nhatnam180804')
#thực hiện truy vấn SQL
query = "SELECT * FROM SalesLT.SalesOrderDetail"
df = pd.read_sql(query,conn)
#đóng kết nối
conn.close()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3136\319593662.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,conn)

# %%
df
# Out:
#      SalesOrderID  SalesOrderDetailID  OrderQty  ProductID  UnitPrice  \
# 0           71774              110562         1        836    356.898
# 1           71774              110563         1        822    356.898
# 2           71776              110567         1        907     63.900
# 3           71780              110616         4        905    218.454
# 4           71780              110617         2        983    461.694
# ..            ...                 ...       ...        ...        ...
# 537         71938              113312         3        715     29.994
# 538         71938              113313         1        881     32.394
# 539         71938              113314         2        875      5.394
# 540         71938              113315         3        800    672.294
# 541         71946              113406         1        916     31.584
#
#      UnitPriceDiscount  LineTotal                               rowguid  \
# ...

# %%
X = DataFrame(df, columns= ['columns name '])
y = DataFrame(df, columns=[' columns name '])

# %%
regression = LinearRegression() #(tạo ra một đối tượng và lưu trữ nó vào **Tham chiếu đến LinearR với biến regression)
regression.fit(X, y)

# %%
regression.coef_ (đây là hệ số góc ) #theta 1

# %%
# điểm cắt trục y theta 0
regression.intercept_

# %%
plt.figure(figsize=(10,6)) #( size của đồ thị)
plt.scatter(X,Y,alpha = 0.3  #(tạo độ trong suốt của biểu đồ) ( tạo một biểu đồ phân tán trong notebook bằng matplotlib.pyplot.scatter())
plt.plot(X,regression.predict(X), color='red',linewidth = 4) #(Vẽ một đường thẳng trong biểu đồ, tính toán giá trị dự đoán cho mỗi ngân sách X)
plt.title(' ') #( tiêu đề cho đồ thị )
plt.xlabel(' ') #(thông tin cho trục hoành)
plt.ylabel(' ') #(thông tin cho trục tung)
plt.ylim(0,m) # miền của y
plt.xlim(0,n) # miền của x
plt.show() #( đưa ra đồ thị )

# %%
regression.score(X,y) # số đo lường R^2
